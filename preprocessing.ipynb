# %% [markdown]
# # goal of this notebook
#
# Before we can use the data we have to prepare it in consumable structure where *period* and *region* are row indices and all other columns are variables (including target ones)
#
# All missing data will be filled with ffill()

# %%
import pandas as pd
from functools import reduce

# %%
df = pd.read_excel(r"numero_uno_11.xlsx")
df
# Out:
#     Unnamed: 0   Unnamed: 1            Unnamed: 2  \
# 0        Index        Index           region_name
# 1            1  14000000000  Белгородская область
# 2            2  15000000000      Брянская область
# 3            3  17000000000  Владимирская область
# 4            4  20000000000   Воронежская область
# ..         ...          ...                   ...
# 171        NaN          NaN                   NaN
# 172        NaN          NaN                   NaN
# 173        NaN          NaN                   NaN
# 174        NaN          NaN                   NaN
# 175        NaN          NaN                   NaN
#
#      Уровень инновационной активности, в процентах (%)  Unnamed: 4  \
# 0                                          2018.000000      2019.0
# 1                                            18.151815        15.1
# 2                                             8.243243        10.1
# 3                                            13.006135        10.5
# 4                                            17.097416        13.4
# ..                                                 ...         ...
# 171                                                NaN         NaN
# 172                                                NaN         NaN
# 173                                                NaN         NaN
# 174                                                NaN         NaN
# 175                                                NaN         NaN
#
#       Unnamed: 5   Unnamed: 6   Unnamed: 7  \
# 0    2020.000000  2021.000000  2022.000000
# 1      18.011895    16.998012    15.130941
# 2      10.943396    13.517442    12.094395
# 3      12.648221    11.666667     9.867173
# 4      15.937500    12.626656    10.436714
# ..           ...          ...          ...
# 171          NaN          NaN          NaN
# 172          NaN          NaN          NaN
# 173          NaN          NaN          NaN
# 174          NaN          NaN          NaN
# 175          NaN          NaN          NaN
#
#      Индекс производительности труда по Российской Федерации, \nпо субъектам Российской Федерации в 2008-2022 г.г. (в % к предыдущему году)  \
# 0                                               2018.0
# 1                                                102.8
# 2                                                104.9
# 3                                                100.8
# 4                                                102.7
# ..                                                 ...
# 171                                                NaN
# 172                                                NaN
# 173                                                NaN
# 174                                                NaN
# 175                                                NaN
#
#      Unnamed: 9  ...  \
# 0        2019.0  ...
# 1         102.2  ...
# 2         105.0  ...
# 3         104.0  ...
# 4         102.0  ...
# ..          ...  ...
# 171         NaN  ...
# 172         NaN  ...
# 173         NaN  ...
# 174         NaN  ...
# 175         NaN  ...
#
#      11411000200010200019 Объем инвестиций в основной капитал (за исключением бюджетных средств) с 2018 г.(тыс. руб.)  \
# 0                                              2018 г.
# 1                                            122692316
# 2                                          51322637,99
# 3                                             64891800
# 4                                         237032908,99
# ..                                                 ...
# 171                                                NaN
# 172                                                NaN
# 173                                                NaN
# 174                                                NaN
# 175                                                NaN
#
#      Unnamed: 419  Unnamed: 420  Unnamed: 421  Unnamed: 422  \
# 0         2019 г.       2020 г.       2021 г.       2022 г.
# 1       147140843     148193081  150464999,99  166351412,99
# 2     52841525,99      61748381      71453729      75388303
# 3     77123595,99      79480131   71849385,99      82673964
# 4       248907057  208205274,99  239142522,99     273153509
# ..            ...           ...           ...           ...
# 171           NaN           NaN           NaN           NaN
# 172           NaN           NaN           NaN           NaN
# 173           NaN           NaN           NaN           NaN
# 174           NaN           NaN           NaN           NaN
# 175           NaN           NaN           NaN           NaN
#
#      11111110200300200001 Текущая рыночная стоимость жилых зданий(млн. руб.)  \
# 0                                              2018 г.
# 1                                           1305087,99
# 2                                            727575,99
# 3                                            927909,99
# 4                                           1364237,99
# ..                                                 ...
# 171                                                NaN
# 172                                                NaN
# 173                                                NaN
# 174                                                NaN
# 175                                                NaN
#
#      Unnamed: 424  Unnamed: 425  Unnamed: 426  Unnamed: 427
# 0         2019 г.       2020 г.       2021 г.       2022 г.
# 1      1343136,99    1383018,99    1531325,99    1782291,99
# 2       715541,99     733878,99     750697,99     774654,99
# 3       959045,99     933258,99     964891,99    1325435,99
# 4      1366961,99    1472497,99    1753907,99    2421244,99
# ..            ...           ...           ...           ...
# 171           NaN           NaN           NaN           NaN
# 172           NaN           NaN           NaN           NaN
# 173           NaN           NaN           NaN           NaN
# 174           NaN           NaN           NaN           NaN
# 175           NaN           NaN           NaN           NaN
#
# [176 rows x 428 columns]

# %%
df.columns.tolist()
# Out:
# ['Unnamed: 0',
#  'Unnamed: 1',
#  'Unnamed: 2',
#  'Уровень инновационной активности, в процентах (%)',
#  'Unnamed: 4',
#  'Unnamed: 5',
#  'Unnamed: 6',
#  'Unnamed: 7',
#  'Индекс производительности труда по Российской Федерации, \nпо субъектам Российской Федерации в 2008-2022 г.г. (в % к предыдущему году)',
#  'Unnamed: 9',
#  'Unnamed: 10',
#  'Unnamed: 11',
#  'Unnamed: 12',
#  'Уровень бедности, в процентах (%) от общей численности населения',
#  'Unnamed: 14',
#  'Unnamed: 15',
#  'Unnamed: 16',
#  'Unnamed: 17',
#  'Индекс промышленного производства в % к соответствующему периоду предыдущего года',
#  'Unnamed: 19',
#  'Unnamed: 20',
#  'Unnamed: 21',
#  'Unnamed: 22',
#  'Распределение объема работ, выполненных по виду деятельности "Строительство" организациями различных форм собственности \n(без учета субъектов малого предпринимательства) \n(тыс. рублей)',
#  'Unnamed: 24',
#  'Unnamed: 25',
#  'Unnamed: 26',
#  'Unnamed: 27',
#  'Среднедушевые денежные доходы населения по субъектам Российской Федерации, руб./месяц',
#  'Unnamed: 29',
#  'Unnamed: 30',
#  'Unnamed: 31',
#  'Unnamed: 32',
#  'Численность занятых в возрасте 15 лет и старше по субъектам Российской Федерации (по данным выборочных обследований), тыс. человек ',
#  'Unnamed: 34',
#  'Unnamed: 35',
#  'Unnamed: 36',
#  'Unnamed: 37',
#  'Уровень занятости населения в возрасте 15 лет и старше по субъектам Российской Федерации (по данным выборочных обследований), в процентах',
#  'Unnamed: 39',
#  'Unnamed: 40',
#  'Unnamed: 41',
#  'Unnamed: 42',
#  'Прирост высокопроизводительных рабочих мест по субъектам Российской Федерации за 2012-2023 гг., тыс. единиц',
#  'Unnamed: 44',
#  'Unnamed: 45',
#  'Unnamed: 46',
#  'Unnamed: 47',
#  'Индекс выпуска товаров и услуг по базовым видам экономической деятельности по субъектам Российской Федерации и федеральным округам\n(к соответствующему периоду предыдущего года, %)',
#  'Unnamed: 49',
#  'Unnamed: 50',
#  'Unnamed: 51',
#  'Unnamed: 52',
#  'Количество собственных легковых автомобилей на 1000 человек населения по субъектам Российской Федерации (на конец года; штук)          ',
#  'Unnamed: 54',
#  'Unnamed: 55',
#  'Unnamed: 56',
#  'Unnamed: 57',
#  'Демографические показатели предприятий по субъектам Российской Федерации в 2018г.\n(единиц) Количество активных предприятий',
#  'Unnamed: 59',
#  'Unnamed: 60',
#  'Unnamed: 61',
#  'Unnamed: 62',
#  'Демографические показатели предприятий по субъектам Российской Федерации в 2018г.\n(единиц) Количество умерших предприятий',
#  'Unnamed: 64',
#  'Unnamed: 65',
#  'Unnamed: 66',
#  'Unnamed: 67',
#  'Грузооборот автомобильного транспорта  по субъектам Российской Федерации (млн.тонно-км)                                                                                                                  ',
#  'Unnamed: 69',
#  'Unnamed: 70',
#  'Unnamed: 71',
#  'Unnamed: 72',
#  'Грузооборот автомобильного транспорта на коммерческой основе (тыс. тонно-км)',
#  'Unnamed: 74',
#  'Unnamed: 75',
#  'Unnamed: 76',
#  'Unnamed: 77',
#  'Доля внутренних затрат на исследования и разработки, в процентах к валовому региональному продукту (ВРП)',
#  'Unnamed: 79',
#  'Unnamed: 80',
#  'Unnamed: 81',
#  'Unnamed: 82',
#  'Доля продаж через Интернет в общем объеме оборота розничной торговли (в фактически действовавших ценах; в процентах)',
#  'Unnamed: 84',
#  'Unnamed: 85',
#  'Unnamed: 86',
#  'Unnamed: 87',
#  'Оборот розничной торговли в расчете на душу населения по субъектам Российской Федерации, рублей',
#  'Unnamed: 89',
#  'Unnamed: 90',
#  'Unnamed: 91',
#  'Unnamed: 92',
#  '23110000100100200001 Общий прирост постоянного населения',
#  'Unnamed: 94',
#  'Unnamed: 95',
#  'Unnamed: 96',
#  'Unnamed: 97',
#  '23110000100040200001 Численность постоянного населения в среднем за год',
#  'Unnamed: 99',
#  'Unnamed: 100',
#  'Unnamed: 101',
#  'Unnamed: 102',
#  '23210000100020200001 Число родившихся (без мертворожденных) за год',
#  'Unnamed: 104',
#  'Unnamed: 105',
#  'Unnamed: 106',
#  'Unnamed: 107',
#  '23220000400080200001 Возрастные коэффициенты смертности, Оба пола',
#  'Unnamed: 109',
#  'Unnamed: 110',
#  'Unnamed: 111',
#  'Unnamed: 112',
#  '23250000100010200001 Ожидаемая продолжительность жизни при рождении, лет, Оба пола',
#  'Unnamed: 114',
#  'Unnamed: 115',
#  'Unnamed: 116',
#  'Unnamed: 117',
#  '23260000100010200001 Суммарный коэффициент рождаемости',
#  'Unnamed: 119',
#  'Unnamed: 120',
#  'Unnamed: 121',
#  'Unnamed: 122',
#  '23260000300030200001 Возрастные коэффициенты рождаемости (число родившихся в среднем за год на 1000 женщин в возрасте,лет) 15-19',
#  'Unnamed: 124',
#  'Unnamed: 125',
#  'Unnamed: 126',
#  'Unnamed: 127',
#  '23260000300030200001 Возрастные коэффициенты рождаемости (число родившихся в среднем за год на 1000 женщин в возрасте,лет) 20-24',
#  'Unnamed: 129',
#  'Unnamed: 130',
#  'Unnamed: 131',
#  'Unnamed: 132',
#  '23260000300030200001 Возрастные коэффициенты рождаемости (число родившихся в среднем за год на 1000 женщин в возрасте,лет) 25-29',
#  'Unnamed: 134',
#  'Unnamed: 135',
#  'Unnamed: 136',
#  'Unnamed: 137',
#  '23260000300030200001 Возрастные коэффициенты рождаемости (число родившихся в среднем за год на 1000 женщин в возрасте,лет) 30-34',
#  'Unnamed: 139',
#  'Unnamed: 140',
#  'Unnamed: 141',
#  'Unnamed: 142',
#  '23260000300030200001 Возрастные коэффициенты рождаемости (число родившихся в среднем за год на 1000 женщин в возрасте,лет) 35-39',
#  'Unnamed: 144',
#  'Unnamed: 145',
#  'Unnamed: 146',
#  'Unnamed: 147',
#  '23260000300030200001 Возрастные коэффициенты рождаемости (число родившихся в среднем за год на 1000 женщин в возрасте,лет) 40-44',
#  'Unnamed: 149',
#  'Unnamed: 150',
#  'Unnamed: 151',
#  'Unnamed: 152',
#  '23260000300030200001 Возрастные коэффициенты рождаемости (число родившихся в среднем за год на 1000 женщин в возрасте,лет) 45-49',
#  'Unnamed: 154',
#  'Unnamed: 155',
#  'Unnamed: 156',
#  'Unnamed: 157',
#  '23260000300030200001 Возрастные коэффициенты рождаемости (число родившихся в среднем за год на 1000 женщин в возрасте,лет) 50-54',
#  'Unnamed: 159',
#  'Unnamed: 160',
#  'Unnamed: 161',
#  'Unnamed: 162',
#  '23220000100020200002 Число умерших за год',
#  'Unnamed: 164',
#  'Unnamed: 165',
#  'Unnamed: 166',
#  'Unnamed: 167',
#  'tab4-zpl_2022 Среднемесячная номинальная начисленная заработная плата работников по полному кругу организаций в целом по экономике по субъектам Российской Федерации с 2018 года , рублей; в % к предыдущему году',
#  'Unnamed: 169',
#  'Unnamed: 170',
#  'Unnamed: 171',
#  'Unnamed: 172',
#  'tab5-zpl_2022 Реальная среднемесячная начисленная заработная плата работников по субъектам Российской ',
#  'Unnamed: 174',
#  'Unnamed: 175',
#  'Unnamed: 176',
#  'Unnamed: 177',
#  'prs Потенциальная рабочая сила в возрасте 15 лет и старше (тыс.человек)',
#  'Unnamed: 179',
#  'Unnamed: 180',
#  'Unnamed: 181',
#  'Unnamed: 182',
#  's_psr Совокупный показатель уровня безработицы и потенциальной рабочей силы населения в возрасте 15 лет и старше за 2017-2022 гг.',
#  'Unnamed: 184',
#  'Unnamed: 185',
#  'Unnamed: 186',
#  'Unnamed: 187',
#  '22132000300020200001 Коэффициент Джини (индекс концентрации доходов)',
#  'Unnamed: 189',
#  'Unnamed: 190',
#  'Unnamed: 191',
#  'Unnamed: 192',
#  '22111200300270200001 Дефицит дохода',
#  'Unnamed: 194',
#  'Unnamed: 195',
#  'Unnamed: 196',
#  'Unnamed: 197',
#  '23320000100010200001 Число прибывших по полу, возрасту и потокам передвижения, всего  в пределах России',
#  'Unnamed: 199',
#  'Unnamed: 200',
#  'Unnamed: 201',
#  'Unnamed: 202',
#  '23320000100010200001 Число прибывших по полу, возрасту и потокам передвижения, всего международная',
#  'Unnamed: 204',
#  'Unnamed: 205',
#  'Unnamed: 206',
#  'Unnamed: 207',
#  '23320000100020200001 Число выбывших по полу, возрасту и потокам передвижения, всего в пределах России',
#  'Unnamed: 209',
#  'Unnamed: 210',
#  'Unnamed: 211',
#  'Unnamed: 212',
#  '23320000100020200001 Число выбывших по полу, возрасту и потокам передвижения, всего международная',
#  'Unnamed: 214',
#  'Unnamed: 215',
#  'Unnamed: 216',
#  'Unnamed: 217',
#  'Валовой региональный продукт по субъектам Российской Федерации (валовая добавленная стоимость в текущих основных ценах) – всего  (миллионов рублей)',
#  'Unnamed: 219',
#  'Unnamed: 220',
#  'Unnamed: 221',
#  'Unnamed: 222',
#  'Валовой региональный продукт по субъектам Российской Федерации на душу населения (валовая добавленная стоимость в текущих основных ценах) – всего (рублей)',
#  'Unnamed: 224',
#  'Unnamed: 225',
#  'Unnamed: 226',
#  'Unnamed: 227',
#  'Фактическое конечное потребление домашних хозяйств на территории субъектов Российской Федерации - всего Расходы домашних хозяйств (в текущих рыночных ценах; миллионов рублей)',
#  'Unnamed: 229',
#  'Unnamed: 230',
#  'Unnamed: 231',
#  'Unnamed: 232',
#  'Численность рабочей силы в возрасте 15-72 лет по субъектам Российской Федерации, Тыс. человек (по данным выборочных обследований рабочей силы)',
#  'Unnamed: 234',
#  'Unnamed: 235',
#  'Unnamed: 236',
#  'Unnamed: 237',
#  'Уровень участия в рабочей силе населения в возрасте 15-72 лет по субъектам Российской Федерации, В процентах (по данным выборочных обследований рабочей силы)',
#  'Unnamed: 239',
#  'Unnamed: 240',
#  'Unnamed: 241',
#  'Unnamed: 242',
#  'Численность безработных в возрасте 15-72 лет по субъектам Российской Федерации, Тыс. человек (по данным выборочных обследований рабочей силы)',
#  'Unnamed: 244',
#  'Unnamed: 245',
#  'Unnamed: 246',
#  'Unnamed: 247',
#  'Уровень безработицы населения в возрасте 15-72 лет по субъектам Российской Федерации, В процентах (по данным выборочных обследований рабочей силы)',
#  'Unnamed: 249',
#  'Unnamed: 250',
#  'Unnamed: 251',
#  'Unnamed: 252',
#  ' Численность занятых в возрасте 15-72 лет по субъектам Российской Федерации, (по данным выборочных обследований рабочей силы) Тыс. человек',
#  'Unnamed: 254',
#  'Unnamed: 255',
#  'Unnamed: 256',
#  'Unnamed: 257',
#  ' Уровень занятости населения в возрасте 15-72 лет по субъектам Российской Федерации В процентах',
#  'Unnamed: 259',
#  'Unnamed: 260',
#  'Unnamed: 261',
#  'Unnamed: 262',
#  'ЧИСЛЕННОСТЬ ОБУЧАЮЩИХСЯ ОРГАНИЗАЦИЙ, ОСУЩЕСТВЛЯЮЩИХ ОБРАЗОВАТЕЛЬНУЮ ДЕЯТЕЛЬНОСТЬ ПО ОБРАЗОВАТЕЛЬНЫМ ПРОГРАММАМ НАЧАЛЬНОГО, ОСНОВНОГО И СРЕДНЕГО ОБЩЕГО ОБРАЗОВАНИЯ (на начало учебного года; тысяч человек)',
#  'Unnamed: 264',
#  'Unnamed: 265',
#  'Unnamed: 266',
#  'Unnamed: 267',
#  'ВЫПУСК ОБУЧАЮЩИХСЯ ОРГАНИЗАЦИЯМИ, ОСУЩЕСТВЛЯЮЩИХ ОБРАЗОВАТЕЛЬНУЮ ДЕЯТЕЛЬНОСТЬ ПО ОБРАЗОВАТЕЛЬНЫМ ПРОГРАММАМ НАЧАЛЬНОГО, ОСНОВНОГО И СРЕДНЕГО ОБЩЕГО ОБРАЗОВАНИЯ (Выпуск обучающихся с аттестатом об основном общем образовании)',
#  'Unnamed: 269',
#  'Unnamed: 270',
#  'Unnamed: 271',
#  '\xa0',
#  'ВЫПУСК ОБУЧАЮЩИХСЯ ОРГАНИЗАЦИЯМИ, ОСУЩЕСТВЛЯЮЩИХ ОБРАЗОВАТЕЛЬНУЮ ДЕЯТЕЛЬНОСТЬ ПО ОБРАЗОВАТЕЛЬНЫМ ПРОГРАММАМ НАЧАЛЬНОГО, ОСНОВНОГО И СРЕДНЕГО ОБЩЕГО ОБРАЗОВАНИЯ (Выпуск обучающихся с аттестатом о среднем общем образовании)',
#  'Unnamed: 274',
#  'Unnamed: 275',
#  'Unnamed: 276',
#  'Unnamed: 277',
#  'ЧИСЛЕННОСТЬ СТУДЕНТОВ, ОБУЧАЮЩИХСЯ ПО ПРОГРАММАМ ПОДГОТОВКИ КВАЛИФИЦИРОВАННЫХ РАБОЧИХ, СЛУЖАЩИХ,(на конец года;тысяч человек)',
#  'Unnamed: 279',
#  'Unnamed: 280',
#  'Unnamed: 281',
#  'Unnamed: 282',
#  'ПРИЕМ НА ОБУЧЕНИЕ ПО ПРОГРАММАМ ПОДГОТОВКИ КВАЛИФИЦИРОВАННЫХ РАБОЧИХ, СЛУЖАЩИХ,  (тысяч человек)',
#  'Unnamed: 284',
#  'Unnamed: 285',
#  'Unnamed: 286',
#  'Unnamed: 287',
#  'ВЫПУСК КВАЛИФИЦИРОВАННЫХ РАБОЧИХ И СЛУЖАЩИХ, (тысяч человек)',
#  'Unnamed: 289',
#  'Unnamed: 290',
#  'Unnamed: 291',
#  'Unnamed: 292',
#  'ЧИСЛЕННОСТЬ СТУДЕНТОВ, ОБУЧАЮЩИХСЯ ПО ПРОГРАММАМ ПОДГОТОВКИ СПЕЦИАЛИСТОВ СРЕДНЕГО ЗВЕНА, (на начало учебного года; тысяч человек)',
#  'Unnamed: 294',
#  'Unnamed: 295',
#  'Unnamed: 296',
#  'Unnamed: 297',
#  'ЧИСЛЕННОСТЬ СТУДЕНТОВ ГОСУДАРСТВЕННЫХ И МУНИЦИПАЛЬНЫХ ПРОФЕССИОНАЛЬНЫХ ОБРАЗОВАТЕЛЬНЫХ ОРГАНИЗАЦИЙ, ОБУЧАЮЩИХСЯ ПО ПРОГРАММАМ ПОДГОТОВКИ СПЕЦИАЛИСТОВ СРЕДНЕГО ЗВЕНА на 10 000 человек населения, (на начало учебного года; человек)',
#  'Unnamed: 299',
#  'Unnamed: 300',
#  'Unnamed: 301',
#  'Unnamed: 302',
#  'ПРИЕМ НА ОБУЧЕНИЕ ПО ПРОГРАММАМ ПОДГОТОВКИ СПЕЦИАЛИСТОВ СРЕДНЕГО ЗВЕНА, (тысяч человек)',
#  'Unnamed: 304',
#  'Unnamed: 305',
#  'Unnamed: 306',
#  'Unnamed: 307',
#  'ВЫПУСК СПЕЦИАЛИСТОВ   СРЕДНЕГО ЗВЕНА, (тысяч человек)',
#  'Unnamed: 309',
#  'Unnamed: 310',
#  'Unnamed: 311',
#  'Unnamed: 312',
#  'ЧИСЛЕННОСТЬ СТУДЕНТОВ, ОБУЧАЮЩИХСЯ ПО ПРОГРАММАМ БАКАЛАВРИАТА, СПЕЦИАЛИТЕТА, МАГИСТРАТУРЫ, (на начало учебного года; тысяч человек) ',
#  'Unnamed: 314',
#  'Unnamed: 315',
#  'Unnamed: 316',
#  'Unnamed: 317',
#  'ЧИСЛЕННОСТЬ СТУДЕНТОВ, ОБУЧАЮЩИХСЯ ПО ПРОГРАММАМ БАКАЛАВРИАТА, СПЕЦИАЛИТЕТА, МАГИСТРАТУРЫ на 10 000 человек населения, (на начало учебного года; человек)',
#  'Unnamed: 319',
#  'Unnamed: 320',
#  'Unnamed: 321',
#  'Unnamed: 322',
#  'ПРИЕМ НА ОБУЧЕНИЕ ПО ПРОГРАММАМ БАКАЛАВРИАТА, СПЕЦИАЛИТЕТА, МАГИСТРАТУРЫ,  (тысяч человек)',
#  'Unnamed: 324',
#  'Unnamed: 325',
#  'Unnamed: 326',
#  'Unnamed: 327',
#  'ВЫПУСК БАКАЛАВРОВ, СПЕЦИАЛИСТОВ, МАГИСТРОВ, (тысяч человек)',
#  'Unnamed: 329',
#  'Unnamed: 330',
#  'Unnamed: 331',
#  'Unnamed: 332',
#  '23110000100030200007 Численность постоянного населения России по возрасту на 1 января, все население',
#  'Unnamed: 334',
#  'Unnamed: 335',
#  'Unnamed: 336',
#  'Unnamed: 337',
#  '23110000100030200007 Численность постоянного населения России по возрасту на 1 января, Всего в трудоспособном возрасте (для мужчин 16-59,для женщин 16-54)',
#  'Unnamed: 339',
#  'Unnamed: 340',
#  'Unnamed: 341',
#  'Unnamed: 342',
#  '23110000100030200007 Численность постоянного населения России по возрасту на 1 января, Старше трудоспособного',
#  'Unnamed: 344',
#  'Unnamed: 345',
#  'Unnamed: 346',
#  'Unnamed: 347',
#  '11111150100170200001 Протяженность автомобильных дорог общего пользования местного значения, находящихся в собственности муниципальных образований, Всего',
#  'Unnamed: 349',
#  'Unnamed: 350',
#  'Unnamed: 351',
#  'Unnamed: 352',
#  '11111150100170200001 Протяженность автомобильных дорог общего пользования местного значения, находящихся в собственности муниципальных образований, Отвечающие нормативным требованиям',
#  'Unnamed: 354',
#  'Unnamed: 355',
#  'Unnamed: 356',
#  'Unnamed: 357',
#  'Введено в действие общей площади жилых домов на 1000 человек населения (кв. метров общей площади жилых помещений)',
#  'Unnamed: 359',
#  'Unnamed: 360',
#  'Unnamed: 361',
#  'Unnamed: 362',
#  'Индекс производительности труда по Российской Федерации, по субъектам Российской Федерации в 2008-2022 г.г. (в % к предыдущему году)',
#  'Unnamed: 364',
#  'Unnamed: 365',
#  'Unnamed: 366',
#  'Unnamed: 367',
#  'Доля инвестиций в основной капитал к ВРП Доля  инвестиций в основной капитал к ВРП (в %)',
#  'Unnamed: 369',
#  'Unnamed: 370',
#  'Unnamed: 371',
#  'Unnamed: 372',
#  'Прирост высокопроизводительных рабочих мест по субъектам Российской Федерации за 2012-2022 гг. (тыс. единиц)',
#  'Unnamed: 374',
#  'Unnamed: 375',
#  'Unnamed: 376',
#  'Unnamed: 377',
#  'Прирост высокопроизводительных рабочих мест по субъектам Российской Федерации за 2012-2022 гг. (в %)',
#  'Unnamed: 379',
#  'Unnamed: 380',
#  'Unnamed: 381',
#  'Unnamed: 382',
#  '11111150100320200001 Плотность автомобильных дорог с твердым покрытием общего пользования на 1000 кв. км территории (по 2013 г.)',
#  'Unnamed: 384',
#  'Unnamed: 385',
#  'Unnamed: 386',
#  'Unnamed: 387',
#  '22720000300200200001 Общая численность пенсионеров',
#  'Unnamed: 389',
#  'Unnamed: 390',
#  'Unnamed: 391',
#  'Unnamed: 392',
#  '13230000100060200002 Численность врачей всех специальностей (физических лиц) в учреждениях, оказывающих медицинские услуги населению, на конец отчетного года(тыс. чел.)Терапевты',
#  'Unnamed: 394',
#  'Unnamed: 395',
#  'Unnamed: 396',
#  'Unnamed: 397',
#  '13230000100060200002 Численность врачей всех специальностей (физических лиц) в учреждениях, оказывающих медицинские услуги населению, на конец отчетного года(тыс. чел.)Всего врачей',
#  'Unnamed: 399',
#  'Unnamed: 400',
#  'Unnamed: 401',
#  'Unnamed: 402',
#  '22310000100520200001 Количество  введенных  жилых помещений ( квартир ) в расчете на 1000 человек населения',
#  'Unnamed: 404',
#  'Unnamed: 405',
#  'Unnamed: 406',
#  'Unnamed: 407',
#  '22310000200010200001 Средняя факт. стоимость строительства 1 кв.м. общей площади отдельно стоящих жилых домов без пристроек, надстроек и встроенных помещений, Отдельно стоящие здания жилого назначения квартирного типа',
#  'Unnamed: 409',
#  'Unnamed: 410',
#  'Unnamed: 411',
#  'Unnamed: 412',
#  '22310000100030200001 Введено в действие общей площади жилых домов на 1000 человек населения (годовая)',
#  'Unnamed: 414',
#  'Unnamed: 415',
#  'Unnamed: 416',
#  'Unnamed: 417',
#  '11411000200010200019 Объем инвестиций в основной капитал (за исключением бюджетных средств) с 2018 г.(тыс. руб.)',
#  'Unnamed: 419',
#  'Unnamed: 420',
#  'Unnamed: 421',
#  'Unnamed: 422',
#  '11111110200300200001 Текущая рыночная стоимость жилых зданий(млн. руб.)',
#  'Unnamed: 424',
#  'Unnamed: 425',
#  'Unnamed: 426',
#  'Unnamed: 427']

# %%
def split_list_with_condition(lst):
    result = []
    temp = []
    for i in range(len(lst)):
        if 'Unnamed' in lst[i] and (i == len(lst) - 1 or 'Unnamed' not in lst[i+1]):
            temp.append(lst[i])
            if temp:
                result.append(temp)
                temp = []
        else:
            temp.append(lst[i])
    return result

blocks = split_list_with_condition(df.columns.tolist())[1:]
blocks
# Out:
# [['Уровень инновационной активности, в процентах (%)',
#   'Unnamed: 4',
#   'Unnamed: 5',
#   'Unnamed: 6',
#   'Unnamed: 7'],
#  ['Индекс производительности труда по Российской Федерации, \nпо субъектам Российской Федерации в 2008-2022 г.г. (в % к предыдущему году)',
#   'Unnamed: 9',
#   'Unnamed: 10',
#   'Unnamed: 11',
#   'Unnamed: 12'],
#  ['Уровень бедности, в процентах (%) от общей численности населения',
#   'Unnamed: 14',
#   'Unnamed: 15',
#   'Unnamed: 16',
#   'Unnamed: 17'],
#  ['Индекс промышленного производства в % к соответствующему периоду предыдущего года',
#   'Unnamed: 19',
#   'Unnamed: 20',
#   'Unnamed: 21',
#   'Unnamed: 22'],
#  ['Распределение объема работ, выполненных по виду деятельности "Строительство" организациями различных форм собственности \n(без учета субъектов малого предпринимательства) \n(тыс. рублей)',
#   'Unnamed: 24',
#   'Unnamed: 25',
#   'Unnamed: 26',
#   'Unnamed: 27'],
#  ['Среднедушевые денежные доходы населения по субъектам Российской Федерации, руб./месяц',
#   'Unnamed: 29',
#   'Unnamed: 30',
#   'Unnamed: 31',
#   'Unnamed: 32'],
#  ['Численность занятых в возрасте 15 лет и старше по субъектам Российской Федерации (по данным выборочных обследований), тыс. человек ',
#   'Unnamed: 34',
#   'Unnamed: 35',
#   'Unnamed: 36',
#   'Unnamed: 37'],
#  ['Уровень занятости населения в возрасте 15 лет и старше по субъектам Российской Федерации (по данным выборочных обследований), в процентах',
#   'Unnamed: 39',
#   'Unnamed: 40',
#   'Unnamed: 41',
#   'Unnamed: 42'],
#  ['Прирост высокопроизводительных рабочих мест по субъектам Российской Федерации за 2012-2023 гг., тыс. единиц',
#   'Unnamed: 44',
#   'Unnamed: 45',
#   'Unnamed: 46',
#   'Unnamed: 47'],
#  ['Индекс выпуска товаров и услуг по базовым видам экономической деятельности по субъектам Российской Федерации и федеральным округам\n(к соответствующему периоду предыдущего года, %)',
#   'Unnamed: 49',
#   'Unnamed: 50',
#   'Unnamed: 51',
#   'Unnamed: 52'],
#  ['Количество собственных легковых автомобилей на 1000 человек населения по субъектам Российской Федерации (на конец года; штук)          ',
#   'Unnamed: 54',
#   'Unnamed: 55',
#   'Unnamed: 56',
#   'Unnamed: 57'],
#  ['Демографические показатели предприятий по субъектам Российской Федерации в 2018г.\n(единиц) Количество активных предприятий',
#   'Unnamed: 59',
#   'Unnamed: 60',
#   'Unnamed: 61',
#   'Unnamed: 62'],
#  ['Демографические показатели предприятий по субъектам Российской Федерации в 2018г.\n(единиц) Количество умерших предприятий',
#   'Unnamed: 64',
#   'Unnamed: 65',
#   'Unnamed: 66',
#   'Unnamed: 67'],
#  ['Грузооборот автомобильного транспорта  по субъектам Российской Федерации (млн.тонно-км)                                                                                                                  ',
#   'Unnamed: 69',
#   'Unnamed: 70',
#   'Unnamed: 71',
#   'Unnamed: 72'],
#  ['Грузооборот автомобильного транспорта на коммерческой основе (тыс. тонно-км)',
#   'Unnamed: 74',
#   'Unnamed: 75',
#   'Unnamed: 76',
#   'Unnamed: 77'],
#  ['Доля внутренних затрат на исследования и разработки, в процентах к валовому региональному продукту (ВРП)',
#   'Unnamed: 79',
#   'Unnamed: 80',
#   'Unnamed: 81',
#   'Unnamed: 82'],
#  ['Доля продаж через Интернет в общем объеме оборота розничной торговли (в фактически действовавших ценах; в процентах)',
#   'Unnamed: 84',
#   'Unnamed: 85',
#   'Unnamed: 86',
#   'Unnamed: 87'],
#  ['Оборот розничной торговли в расчете на душу населения по субъектам Российской Федерации, рублей',
#   'Unnamed: 89',
#   'Unnamed: 90',
#   'Unnamed: 91',
#   'Unnamed: 92'],
#  ['23110000100100200001 Общий прирост постоянного населения',
#   'Unnamed: 94',
#   'Unnamed: 95',
#   'Unnamed: 96',
#   'Unnamed: 97'],
#  ['23110000100040200001 Численность постоянного населения в среднем за год',
#   'Unnamed: 99',
#   'Unnamed: 100',
#   'Unnamed: 101',
#   'Unnamed: 102'],
#  ['23210000100020200001 Число родившихся (без мертворожденных) за год',
#   'Unnamed: 104',
#   'Unnamed: 105',
#   'Unnamed: 106',
#   'Unnamed: 107'],
#  ['23220000400080200001 Возрастные коэффициенты смертности, Оба пола',
#   'Unnamed: 109',
#   'Unnamed: 110',
#   'Unnamed: 111',
#   'Unnamed: 112'],
#  ['23250000100010200001 Ожидаемая продолжительность жизни при рождении, лет, Оба пола',
#   'Unnamed: 114',
#   'Unnamed: 115',
#   'Unnamed: 116',
#   'Unnamed: 117'],
#  ['23260000100010200001 Суммарный коэффициент рождаемости',
#   'Unnamed: 119',
#   'Unnamed: 120',
#   'Unnamed: 121',
#   'Unnamed: 122'],
#  ['23260000300030200001 Возрастные коэффициенты рождаемости (число родившихся в среднем за год на 1000 женщин в возрасте,лет) 15-19',
#   'Unnamed: 124',
#   'Unnamed: 125',
#   'Unnamed: 126',
#   'Unnamed: 127'],
#  ['23260000300030200001 Возрастные коэффициенты рождаемости (число родившихся в среднем за год на 1000 женщин в возрасте,лет) 20-24',
#   'Unnamed: 129',
#   'Unnamed: 130',
#   'Unnamed: 131',
#   'Unnamed: 132'],
#  ['23260000300030200001 Возрастные коэффициенты рождаемости (число родившихся в среднем за год на 1000 женщин в возрасте,лет) 25-29',
#   'Unnamed: 134',
#   'Unnamed: 135',
#   'Unnamed: 136',
#   'Unnamed: 137'],
#  ['23260000300030200001 Возрастные коэффициенты рождаемости (число родившихся в среднем за год на 1000 женщин в возрасте,лет) 30-34',
#   'Unnamed: 139',
#   'Unnamed: 140',
#   'Unnamed: 141',
#   'Unnamed: 142'],
#  ['23260000300030200001 Возрастные коэффициенты рождаемости (число родившихся в среднем за год на 1000 женщин в возрасте,лет) 35-39',
#   'Unnamed: 144',
#   'Unnamed: 145',
#   'Unnamed: 146',
#   'Unnamed: 147'],
#  ['23260000300030200001 Возрастные коэффициенты рождаемости (число родившихся в среднем за год на 1000 женщин в возрасте,лет) 40-44',
#   'Unnamed: 149',
#   'Unnamed: 150',
#   'Unnamed: 151',
#   'Unnamed: 152'],
#  ['23260000300030200001 Возрастные коэффициенты рождаемости (число родившихся в среднем за год на 1000 женщин в возрасте,лет) 45-49',
#   'Unnamed: 154',
#   'Unnamed: 155',
#   'Unnamed: 156',
#   'Unnamed: 157'],
#  ['23260000300030200001 Возрастные коэффициенты рождаемости (число родившихся в среднем за год на 1000 женщин в возрасте,лет) 50-54',
#   'Unnamed: 159',
#   'Unnamed: 160',
#   'Unnamed: 161',
#   'Unnamed: 162'],
#  ['23220000100020200002 Число умерших за год',
#   'Unnamed: 164',
#   'Unnamed: 165',
#   'Unnamed: 166',
#   'Unnamed: 167'],
#  ['tab4-zpl_2022 Среднемесячная номинальная начисленная заработная плата работников по полному кругу организаций в целом по экономике по субъектам Российской Федерации с 2018 года , рублей; в % к предыдущему году',
#   'Unnamed: 169',
#   'Unnamed: 170',
#   'Unnamed: 171',
#   'Unnamed: 172'],
#  ['tab5-zpl_2022 Реальная среднемесячная начисленная заработная плата работников по субъектам Российской ',
#   'Unnamed: 174',
#   'Unnamed: 175',
#   'Unnamed: 176',
#   'Unnamed: 177'],
#  ['prs Потенциальная рабочая сила в возрасте 15 лет и старше (тыс.человек)',
#   'Unnamed: 179',
#   'Unnamed: 180',
#   'Unnamed: 181',
#   'Unnamed: 182'],
#  ['s_psr Совокупный показатель уровня безработицы и потенциальной рабочей силы населения в возрасте 15 лет и старше за 2017-2022 гг.',
#   'Unnamed: 184',
#   'Unnamed: 185',
#   'Unnamed: 186',
#   'Unnamed: 187'],
#  ['22132000300020200001 Коэффициент Джини (индекс концентрации доходов)',
#   'Unnamed: 189',
#   'Unnamed: 190',
#   'Unnamed: 191',
#   'Unnamed: 192'],
#  ['22111200300270200001 Дефицит дохода',
#   'Unnamed: 194',
#   'Unnamed: 195',
#   'Unnamed: 196',
#   'Unnamed: 197'],
#  ['23320000100010200001 Число прибывших по полу, возрасту и потокам передвижения, всего  в пределах России',
#   'Unnamed: 199',
#   'Unnamed: 200',
#   'Unnamed: 201',
#   'Unnamed: 202'],
#  ['23320000100010200001 Число прибывших по полу, возрасту и потокам передвижения, всего международная',
#   'Unnamed: 204',
#   'Unnamed: 205',
#   'Unnamed: 206',
#   'Unnamed: 207'],
#  ['23320000100020200001 Число выбывших по полу, возрасту и потокам передвижения, всего в пределах России',
#   'Unnamed: 209',
#   'Unnamed: 210',
#   'Unnamed: 211',
#   'Unnamed: 212'],
#  ['23320000100020200001 Число выбывших по полу, возрасту и потокам передвижения, всего международная',
#   'Unnamed: 214',
#   'Unnamed: 215',
#   'Unnamed: 216',
#   'Unnamed: 217'],
#  ['Валовой региональный продукт по субъектам Российской Федерации (валовая добавленная стоимость в текущих основных ценах) – всего  (миллионов рублей)',
#   'Unnamed: 219',
#   'Unnamed: 220',
#   'Unnamed: 221',
#   'Unnamed: 222'],
#  ['Валовой региональный продукт по субъектам Российской Федерации на душу населения (валовая добавленная стоимость в текущих основных ценах) – всего (рублей)',
#   'Unnamed: 224',
#   'Unnamed: 225',
#   'Unnamed: 226',
#   'Unnamed: 227'],
#  ['Фактическое конечное потребление домашних хозяйств на территории субъектов Российской Федерации - всего Расходы домашних хозяйств (в текущих рыночных ценах; миллионов рублей)',
#   'Unnamed: 229',
#   'Unnamed: 230',
#   'Unnamed: 231',
#   'Unnamed: 232'],
#  ['Численность рабочей силы в возрасте 15-72 лет по субъектам Российской Федерации, Тыс. человек (по данным выборочных обследований рабочей силы)',
#   'Unnamed: 234',
#   'Unnamed: 235',
#   'Unnamed: 236',
#   'Unnamed: 237'],
#  ['Уровень участия в рабочей силе населения в возрасте 15-72 лет по субъектам Российской Федерации, В процентах (по данным выборочных обследований рабочей силы)',
#   'Unnamed: 239',
#   'Unnamed: 240',
#   'Unnamed: 241',
#   'Unnamed: 242'],
#  ['Численность безработных в возрасте 15-72 лет по субъектам Российской Федерации, Тыс. человек (по данным выборочных обследований рабочей силы)',
#   'Unnamed: 244',
#   'Unnamed: 245',
#   'Unnamed: 246',
#   'Unnamed: 247'],
#  ['Уровень безработицы населения в возрасте 15-72 лет по субъектам Российской Федерации, В процентах (по данным выборочных обследований рабочей силы)',
#   'Unnamed: 249',
#   'Unnamed: 250',
#   'Unnamed: 251',
#   'Unnamed: 252'],
#  [' Численность занятых в возрасте 15-72 лет по субъектам Российской Федерации, (по данным выборочных обследований рабочей силы) Тыс. человек',
#   'Unnamed: 254',
#   'Unnamed: 255',
#   'Unnamed: 256',
#   'Unnamed: 257'],
#  [' Уровень занятости населения в возрасте 15-72 лет по субъектам Российской Федерации В процентах',
#   'Unnamed: 259',
#   'Unnamed: 260',
#   'Unnamed: 261',
#   'Unnamed: 262'],
#  ['ЧИСЛЕННОСТЬ ОБУЧАЮЩИХСЯ ОРГАНИЗАЦИЙ, ОСУЩЕСТВЛЯЮЩИХ ОБРАЗОВАТЕЛЬНУЮ ДЕЯТЕЛЬНОСТЬ ПО ОБРАЗОВАТЕЛЬНЫМ ПРОГРАММАМ НАЧАЛЬНОГО, ОСНОВНОГО И СРЕДНЕГО ОБЩЕГО ОБРАЗОВАНИЯ (на начало учебного года; тысяч человек)',
#   'Unnamed: 264',
#   'Unnamed: 265',
#   'Unnamed: 266',
#   'Unnamed: 267'],
#  ['ВЫПУСК ОБУЧАЮЩИХСЯ ОРГАНИЗАЦИЯМИ, ОСУЩЕСТВЛЯЮЩИХ ОБРАЗОВАТЕЛЬНУЮ ДЕЯТЕЛЬНОСТЬ ПО ОБРАЗОВАТЕЛЬНЫМ ПРОГРАММАМ НАЧАЛЬНОГО, ОСНОВНОГО И СРЕДНЕГО ОБЩЕГО ОБРАЗОВАНИЯ (Выпуск обучающихся с аттестатом об основном общем образовании)',
#   'Unnamed: 269',
#   'Unnamed: 270',
#   'Unnamed: 271'],
#  ['\xa0',
#   'ВЫПУСК ОБУЧАЮЩИХСЯ ОРГАНИЗАЦИЯМИ, ОСУЩЕСТВЛЯЮЩИХ ОБРАЗОВАТЕЛЬНУЮ ДЕЯТЕЛЬНОСТЬ ПО ОБРАЗОВАТЕЛЬНЫМ ПРОГРАММАМ НАЧАЛЬНОГО, ОСНОВНОГО И СРЕДНЕГО ОБЩЕГО ОБРАЗОВАНИЯ (Выпуск обучающихся с аттестатом о среднем общем образовании)',
#   'Unnamed: 274',
#   'Unnamed: 275',
#   'Unnamed: 276',
#   'Unnamed: 277'],
#  ['ЧИСЛЕННОСТЬ СТУДЕНТОВ, ОБУЧАЮЩИХСЯ ПО ПРОГРАММАМ ПОДГОТОВКИ КВАЛИФИЦИРОВАННЫХ РАБОЧИХ, СЛУЖАЩИХ,(на конец года;тысяч человек)',
#   'Unnamed: 279',
#   'Unnamed: 280',
#   'Unnamed: 281',
#   'Unnamed: 282'],
#  ['ПРИЕМ НА ОБУЧЕНИЕ ПО ПРОГРАММАМ ПОДГОТОВКИ КВАЛИФИЦИРОВАННЫХ РАБОЧИХ, СЛУЖАЩИХ,  (тысяч человек)',
#   'Unnamed: 284',
#   'Unnamed: 285',
#   'Unnamed: 286',
#   'Unnamed: 287'],
#  ['ВЫПУСК КВАЛИФИЦИРОВАННЫХ РАБОЧИХ И СЛУЖАЩИХ, (тысяч человек)',
#   'Unnamed: 289',
#   'Unnamed: 290',
#   'Unnamed: 291',
#   'Unnamed: 292'],
#  ['ЧИСЛЕННОСТЬ СТУДЕНТОВ, ОБУЧАЮЩИХСЯ ПО ПРОГРАММАМ ПОДГОТОВКИ СПЕЦИАЛИСТОВ СРЕДНЕГО ЗВЕНА, (на начало учебного года; тысяч человек)',
#   'Unnamed: 294',
#   'Unnamed: 295',
#   'Unnamed: 296',
#   'Unnamed: 297'],
#  ['ЧИСЛЕННОСТЬ СТУДЕНТОВ ГОСУДАРСТВЕННЫХ И МУНИЦИПАЛЬНЫХ ПРОФЕССИОНАЛЬНЫХ ОБРАЗОВАТЕЛЬНЫХ ОРГАНИЗАЦИЙ, ОБУЧАЮЩИХСЯ ПО ПРОГРАММАМ ПОДГОТОВКИ СПЕЦИАЛИСТОВ СРЕДНЕГО ЗВЕНА на 10 000 человек населения, (на начало учебного года; человек)',
#   'Unnamed: 299',
#   'Unnamed: 300',
#   'Unnamed: 301',
#   'Unnamed: 302'],
#  ['ПРИЕМ НА ОБУЧЕНИЕ ПО ПРОГРАММАМ ПОДГОТОВКИ СПЕЦИАЛИСТОВ СРЕДНЕГО ЗВЕНА, (тысяч человек)',
#   'Unnamed: 304',
#   'Unnamed: 305',
#   'Unnamed: 306',
#   'Unnamed: 307'],
#  ['ВЫПУСК СПЕЦИАЛИСТОВ   СРЕДНЕГО ЗВЕНА, (тысяч человек)',
#   'Unnamed: 309',
#   'Unnamed: 310',
#   'Unnamed: 311',
#   'Unnamed: 312'],
#  ['ЧИСЛЕННОСТЬ СТУДЕНТОВ, ОБУЧАЮЩИХСЯ ПО ПРОГРАММАМ БАКАЛАВРИАТА, СПЕЦИАЛИТЕТА, МАГИСТРАТУРЫ, (на начало учебного года; тысяч человек) ',
#   'Unnamed: 314',
#   'Unnamed: 315',
#   'Unnamed: 316',
#   'Unnamed: 317'],
#  ['ЧИСЛЕННОСТЬ СТУДЕНТОВ, ОБУЧАЮЩИХСЯ ПО ПРОГРАММАМ БАКАЛАВРИАТА, СПЕЦИАЛИТЕТА, МАГИСТРАТУРЫ на 10 000 человек населения, (на начало учебного года; человек)',
#   'Unnamed: 319',
#   'Unnamed: 320',
#   'Unnamed: 321',
#   'Unnamed: 322'],
#  ['ПРИЕМ НА ОБУЧЕНИЕ ПО ПРОГРАММАМ БАКАЛАВРИАТА, СПЕЦИАЛИТЕТА, МАГИСТРАТУРЫ,  (тысяч человек)',
#   'Unnamed: 324',
#   'Unnamed: 325',
#   'Unnamed: 326',
#   'Unnamed: 327'],
#  ['ВЫПУСК БАКАЛАВРОВ, СПЕЦИАЛИСТОВ, МАГИСТРОВ, (тысяч человек)',
#   'Unnamed: 329',
#   'Unnamed: 330',
#   'Unnamed: 331',
#   'Unnamed: 332'],
#  ['23110000100030200007 Численность постоянного населения России по возрасту на 1 января, все население',
#   'Unnamed: 334',
#   'Unnamed: 335',
#   'Unnamed: 336',
#   'Unnamed: 337'],
#  ['23110000100030200007 Численность постоянного населения России по возрасту на 1 января, Всего в трудоспособном возрасте (для мужчин 16-59,для женщин 16-54)',
#   'Unnamed: 339',
#   'Unnamed: 340',
#   'Unnamed: 341',
#   'Unnamed: 342'],
#  ['23110000100030200007 Численность постоянного населения России по возрасту на 1 января, Старше трудоспособного',
#   'Unnamed: 344',
#   'Unnamed: 345',
#   'Unnamed: 346',
#   'Unnamed: 347'],
#  ['11111150100170200001 Протяженность автомобильных дорог общего пользования местного значения, находящихся в собственности муниципальных образований, Всего',
#   'Unnamed: 349',
#   'Unnamed: 350',
#   'Unnamed: 351',
#   'Unnamed: 352'],
#  ['11111150100170200001 Протяженность автомобильных дорог общего пользования местного значения, находящихся в собственности муниципальных образований, Отвечающие нормативным требованиям',
#   'Unnamed: 354',
#   'Unnamed: 355',
#   'Unnamed: 356',
#   'Unnamed: 357'],
#  ['Введено в действие общей площади жилых домов на 1000 человек населения (кв. метров общей площади жилых помещений)',
#   'Unnamed: 359',
#   'Unnamed: 360',
#   'Unnamed: 361',
#   'Unnamed: 362'],
#  ['Индекс производительности труда по Российской Федерации, по субъектам Российской Федерации в 2008-2022 г.г. (в % к предыдущему году)',
#   'Unnamed: 364',
#   'Unnamed: 365',
#   'Unnamed: 366',
#   'Unnamed: 367'],
#  ['Доля инвестиций в основной капитал к ВРП Доля  инвестиций в основной капитал к ВРП (в %)',
#   'Unnamed: 369',
#   'Unnamed: 370',
#   'Unnamed: 371',
#   'Unnamed: 372'],
#  ['Прирост высокопроизводительных рабочих мест по субъектам Российской Федерации за 2012-2022 гг. (тыс. единиц)',
#   'Unnamed: 374',
#   'Unnamed: 375',
#   'Unnamed: 376',
#   'Unnamed: 377'],
#  ['Прирост высокопроизводительных рабочих мест по субъектам Российской Федерации за 2012-2022 гг. (в %)',
#   'Unnamed: 379',
#   'Unnamed: 380',
#   'Unnamed: 381',
#   'Unnamed: 382'],
#  ['11111150100320200001 Плотность автомобильных дорог с твердым покрытием общего пользования на 1000 кв. км территории (по 2013 г.)',
#   'Unnamed: 384',
#   'Unnamed: 385',
#   'Unnamed: 386',
#   'Unnamed: 387'],
#  ['22720000300200200001 Общая численность пенсионеров',
#   'Unnamed: 389',
#   'Unnamed: 390',
#   'Unnamed: 391',
#   'Unnamed: 392'],
#  ['13230000100060200002 Численность врачей всех специальностей (физических лиц) в учреждениях, оказывающих медицинские услуги населению, на конец отчетного года(тыс. чел.)Терапевты',
#   'Unnamed: 394',
#   'Unnamed: 395',
#   'Unnamed: 396',
#   'Unnamed: 397'],
#  ['13230000100060200002 Численность врачей всех специальностей (физических лиц) в учреждениях, оказывающих медицинские услуги населению, на конец отчетного года(тыс. чел.)Всего врачей',
#   'Unnamed: 399',
#   'Unnamed: 400',
#   'Unnamed: 401',
#   'Unnamed: 402'],
#  ['22310000100520200001 Количество  введенных  жилых помещений ( квартир ) в расчете на 1000 человек населения',
#   'Unnamed: 404',
#   'Unnamed: 405',
#   'Unnamed: 406',
#   'Unnamed: 407'],
#  ['22310000200010200001 Средняя факт. стоимость строительства 1 кв.м. общей площади отдельно стоящих жилых домов без пристроек, надстроек и встроенных помещений, Отдельно стоящие здания жилого назначения квартирного типа',
#   'Unnamed: 409',
#   'Unnamed: 410',
#   'Unnamed: 411',
#   'Unnamed: 412'],
#  ['22310000100030200001 Введено в действие общей площади жилых домов на 1000 человек населения (годовая)',
#   'Unnamed: 414',
#   'Unnamed: 415',
#   'Unnamed: 416',
#   'Unnamed: 417'],
#  ['11411000200010200019 Объем инвестиций в основной капитал (за исключением бюджетных средств) с 2018 г.(тыс. руб.)',
#   'Unnamed: 419',
#   'Unnamed: 420',
#   'Unnamed: 421',
#   'Unnamed: 422'],
#  ['11111110200300200001 Текущая рыночная стоимость жилых зданий(млн. руб.)',
#   'Unnamed: 424',
#   'Unnamed: 425',
#   'Unnamed: 426',
#   'Unnamed: 427']]

# %%
true_blocks = [col for col in blocks if len(col) == 5]
true_blocks
# Out:
# [['Уровень инновационной активности, в процентах (%)',
#   'Unnamed: 4',
#   'Unnamed: 5',
#   'Unnamed: 6',
#   'Unnamed: 7'],
#  ['Индекс производительности труда по Российской Федерации, \nпо субъектам Российской Федерации в 2008-2022 г.г. (в % к предыдущему году)',
#   'Unnamed: 9',
#   'Unnamed: 10',
#   'Unnamed: 11',
#   'Unnamed: 12'],
#  ['Уровень бедности, в процентах (%) от общей численности населения',
#   'Unnamed: 14',
#   'Unnamed: 15',
#   'Unnamed: 16',
#   'Unnamed: 17'],
#  ['Индекс промышленного производства в % к соответствующему периоду предыдущего года',
#   'Unnamed: 19',
#   'Unnamed: 20',
#   'Unnamed: 21',
#   'Unnamed: 22'],
#  ['Распределение объема работ, выполненных по виду деятельности "Строительство" организациями различных форм собственности \n(без учета субъектов малого предпринимательства) \n(тыс. рублей)',
#   'Unnamed: 24',
#   'Unnamed: 25',
#   'Unnamed: 26',
#   'Unnamed: 27'],
#  ['Среднедушевые денежные доходы населения по субъектам Российской Федерации, руб./месяц',
#   'Unnamed: 29',
#   'Unnamed: 30',
#   'Unnamed: 31',
#   'Unnamed: 32'],
#  ['Численность занятых в возрасте 15 лет и старше по субъектам Российской Федерации (по данным выборочных обследований), тыс. человек ',
#   'Unnamed: 34',
#   'Unnamed: 35',
#   'Unnamed: 36',
#   'Unnamed: 37'],
#  ['Уровень занятости населения в возрасте 15 лет и старше по субъектам Российской Федерации (по данным выборочных обследований), в процентах',
#   'Unnamed: 39',
#   'Unnamed: 40',
#   'Unnamed: 41',
#   'Unnamed: 42'],
#  ['Прирост высокопроизводительных рабочих мест по субъектам Российской Федерации за 2012-2023 гг., тыс. единиц',
#   'Unnamed: 44',
#   'Unnamed: 45',
#   'Unnamed: 46',
#   'Unnamed: 47'],
#  ['Индекс выпуска товаров и услуг по базовым видам экономической деятельности по субъектам Российской Федерации и федеральным округам\n(к соответствующему периоду предыдущего года, %)',
#   'Unnamed: 49',
#   'Unnamed: 50',
#   'Unnamed: 51',
#   'Unnamed: 52'],
#  ['Количество собственных легковых автомобилей на 1000 человек населения по субъектам Российской Федерации (на конец года; штук)          ',
#   'Unnamed: 54',
#   'Unnamed: 55',
#   'Unnamed: 56',
#   'Unnamed: 57'],
#  ['Демографические показатели предприятий по субъектам Российской Федерации в 2018г.\n(единиц) Количество активных предприятий',
#   'Unnamed: 59',
#   'Unnamed: 60',
#   'Unnamed: 61',
#   'Unnamed: 62'],
#  ['Демографические показатели предприятий по субъектам Российской Федерации в 2018г.\n(единиц) Количество умерших предприятий',
#   'Unnamed: 64',
#   'Unnamed: 65',
#   'Unnamed: 66',
#   'Unnamed: 67'],
#  ['Грузооборот автомобильного транспорта  по субъектам Российской Федерации (млн.тонно-км)                                                                                                                  ',
#   'Unnamed: 69',
#   'Unnamed: 70',
#   'Unnamed: 71',
#   'Unnamed: 72'],
#  ['Грузооборот автомобильного транспорта на коммерческой основе (тыс. тонно-км)',
#   'Unnamed: 74',
#   'Unnamed: 75',
#   'Unnamed: 76',
#   'Unnamed: 77'],
#  ['Доля внутренних затрат на исследования и разработки, в процентах к валовому региональному продукту (ВРП)',
#   'Unnamed: 79',
#   'Unnamed: 80',
#   'Unnamed: 81',
#   'Unnamed: 82'],
#  ['Доля продаж через Интернет в общем объеме оборота розничной торговли (в фактически действовавших ценах; в процентах)',
#   'Unnamed: 84',
#   'Unnamed: 85',
#   'Unnamed: 86',
#   'Unnamed: 87'],
#  ['Оборот розничной торговли в расчете на душу населения по субъектам Российской Федерации, рублей',
#   'Unnamed: 89',
#   'Unnamed: 90',
#   'Unnamed: 91',
#   'Unnamed: 92'],
#  ['23110000100100200001 Общий прирост постоянного населения',
#   'Unnamed: 94',
#   'Unnamed: 95',
#   'Unnamed: 96',
#   'Unnamed: 97'],
#  ['23110000100040200001 Численность постоянного населения в среднем за год',
#   'Unnamed: 99',
#   'Unnamed: 100',
#   'Unnamed: 101',
#   'Unnamed: 102'],
#  ['23210000100020200001 Число родившихся (без мертворожденных) за год',
#   'Unnamed: 104',
#   'Unnamed: 105',
#   'Unnamed: 106',
#   'Unnamed: 107'],
#  ['23220000400080200001 Возрастные коэффициенты смертности, Оба пола',
#   'Unnamed: 109',
#   'Unnamed: 110',
#   'Unnamed: 111',
#   'Unnamed: 112'],
#  ['23250000100010200001 Ожидаемая продолжительность жизни при рождении, лет, Оба пола',
#   'Unnamed: 114',
#   'Unnamed: 115',
#   'Unnamed: 116',
#   'Unnamed: 117'],
#  ['23260000100010200001 Суммарный коэффициент рождаемости',
#   'Unnamed: 119',
#   'Unnamed: 120',
#   'Unnamed: 121',
#   'Unnamed: 122'],
#  ['23260000300030200001 Возрастные коэффициенты рождаемости (число родившихся в среднем за год на 1000 женщин в возрасте,лет) 15-19',
#   'Unnamed: 124',
#   'Unnamed: 125',
#   'Unnamed: 126',
#   'Unnamed: 127'],
#  ['23260000300030200001 Возрастные коэффициенты рождаемости (число родившихся в среднем за год на 1000 женщин в возрасте,лет) 20-24',
#   'Unnamed: 129',
#   'Unnamed: 130',
#   'Unnamed: 131',
#   'Unnamed: 132'],
#  ['23260000300030200001 Возрастные коэффициенты рождаемости (число родившихся в среднем за год на 1000 женщин в возрасте,лет) 25-29',
#   'Unnamed: 134',
#   'Unnamed: 135',
#   'Unnamed: 136',
#   'Unnamed: 137'],
#  ['23260000300030200001 Возрастные коэффициенты рождаемости (число родившихся в среднем за год на 1000 женщин в возрасте,лет) 30-34',
#   'Unnamed: 139',
#   'Unnamed: 140',
#   'Unnamed: 141',
#   'Unnamed: 142'],
#  ['23260000300030200001 Возрастные коэффициенты рождаемости (число родившихся в среднем за год на 1000 женщин в возрасте,лет) 35-39',
#   'Unnamed: 144',
#   'Unnamed: 145',
#   'Unnamed: 146',
#   'Unnamed: 147'],
#  ['23260000300030200001 Возрастные коэффициенты рождаемости (число родившихся в среднем за год на 1000 женщин в возрасте,лет) 40-44',
#   'Unnamed: 149',
#   'Unnamed: 150',
#   'Unnamed: 151',
#   'Unnamed: 152'],
#  ['23260000300030200001 Возрастные коэффициенты рождаемости (число родившихся в среднем за год на 1000 женщин в возрасте,лет) 45-49',
#   'Unnamed: 154',
#   'Unnamed: 155',
#   'Unnamed: 156',
#   'Unnamed: 157'],
#  ['23260000300030200001 Возрастные коэффициенты рождаемости (число родившихся в среднем за год на 1000 женщин в возрасте,лет) 50-54',
#   'Unnamed: 159',
#   'Unnamed: 160',
#   'Unnamed: 161',
#   'Unnamed: 162'],
#  ['23220000100020200002 Число умерших за год',
#   'Unnamed: 164',
#   'Unnamed: 165',
#   'Unnamed: 166',
#   'Unnamed: 167'],
#  ['tab4-zpl_2022 Среднемесячная номинальная начисленная заработная плата работников по полному кругу организаций в целом по экономике по субъектам Российской Федерации с 2018 года , рублей; в % к предыдущему году',
#   'Unnamed: 169',
#   'Unnamed: 170',
#   'Unnamed: 171',
#   'Unnamed: 172'],
#  ['tab5-zpl_2022 Реальная среднемесячная начисленная заработная плата работников по субъектам Российской ',
#   'Unnamed: 174',
#   'Unnamed: 175',
#   'Unnamed: 176',
#   'Unnamed: 177'],
#  ['prs Потенциальная рабочая сила в возрасте 15 лет и старше (тыс.человек)',
#   'Unnamed: 179',
#   'Unnamed: 180',
#   'Unnamed: 181',
#   'Unnamed: 182'],
#  ['s_psr Совокупный показатель уровня безработицы и потенциальной рабочей силы населения в возрасте 15 лет и старше за 2017-2022 гг.',
#   'Unnamed: 184',
#   'Unnamed: 185',
#   'Unnamed: 186',
#   'Unnamed: 187'],
#  ['22132000300020200001 Коэффициент Джини (индекс концентрации доходов)',
#   'Unnamed: 189',
#   'Unnamed: 190',
#   'Unnamed: 191',
#   'Unnamed: 192'],
#  ['22111200300270200001 Дефицит дохода',
#   'Unnamed: 194',
#   'Unnamed: 195',
#   'Unnamed: 196',
#   'Unnamed: 197'],
#  ['23320000100010200001 Число прибывших по полу, возрасту и потокам передвижения, всего  в пределах России',
#   'Unnamed: 199',
#   'Unnamed: 200',
#   'Unnamed: 201',
#   'Unnamed: 202'],
#  ['23320000100010200001 Число прибывших по полу, возрасту и потокам передвижения, всего международная',
#   'Unnamed: 204',
#   'Unnamed: 205',
#   'Unnamed: 206',
#   'Unnamed: 207'],
#  ['23320000100020200001 Число выбывших по полу, возрасту и потокам передвижения, всего в пределах России',
#   'Unnamed: 209',
#   'Unnamed: 210',
#   'Unnamed: 211',
#   'Unnamed: 212'],
#  ['23320000100020200001 Число выбывших по полу, возрасту и потокам передвижения, всего международная',
#   'Unnamed: 214',
#   'Unnamed: 215',
#   'Unnamed: 216',
#   'Unnamed: 217'],
#  ['Валовой региональный продукт по субъектам Российской Федерации (валовая добавленная стоимость в текущих основных ценах) – всего  (миллионов рублей)',
#   'Unnamed: 219',
#   'Unnamed: 220',
#   'Unnamed: 221',
#   'Unnamed: 222'],
#  ['Валовой региональный продукт по субъектам Российской Федерации на душу населения (валовая добавленная стоимость в текущих основных ценах) – всего (рублей)',
#   'Unnamed: 224',
#   'Unnamed: 225',
#   'Unnamed: 226',
#   'Unnamed: 227'],
#  ['Фактическое конечное потребление домашних хозяйств на территории субъектов Российской Федерации - всего Расходы домашних хозяйств (в текущих рыночных ценах; миллионов рублей)',
#   'Unnamed: 229',
#   'Unnamed: 230',
#   'Unnamed: 231',
#   'Unnamed: 232'],
#  ['Численность рабочей силы в возрасте 15-72 лет по субъектам Российской Федерации, Тыс. человек (по данным выборочных обследований рабочей силы)',
#   'Unnamed: 234',
#   'Unnamed: 235',
#   'Unnamed: 236',
#   'Unnamed: 237'],
#  ['Уровень участия в рабочей силе населения в возрасте 15-72 лет по субъектам Российской Федерации, В процентах (по данным выборочных обследований рабочей силы)',
#   'Unnamed: 239',
#   'Unnamed: 240',
#   'Unnamed: 241',
#   'Unnamed: 242'],
#  ['Численность безработных в возрасте 15-72 лет по субъектам Российской Федерации, Тыс. человек (по данным выборочных обследований рабочей силы)',
#   'Unnamed: 244',
#   'Unnamed: 245',
#   'Unnamed: 246',
#   'Unnamed: 247'],
#  ['Уровень безработицы населения в возрасте 15-72 лет по субъектам Российской Федерации, В процентах (по данным выборочных обследований рабочей силы)',
#   'Unnamed: 249',
#   'Unnamed: 250',
#   'Unnamed: 251',
#   'Unnamed: 252'],
#  [' Численность занятых в возрасте 15-72 лет по субъектам Российской Федерации, (по данным выборочных обследований рабочей силы) Тыс. человек',
#   'Unnamed: 254',
#   'Unnamed: 255',
#   'Unnamed: 256',
#   'Unnamed: 257'],
#  [' Уровень занятости населения в возрасте 15-72 лет по субъектам Российской Федерации В процентах',
#   'Unnamed: 259',
#   'Unnamed: 260',
#   'Unnamed: 261',
#   'Unnamed: 262'],
#  ['ЧИСЛЕННОСТЬ ОБУЧАЮЩИХСЯ ОРГАНИЗАЦИЙ, ОСУЩЕСТВЛЯЮЩИХ ОБРАЗОВАТЕЛЬНУЮ ДЕЯТЕЛЬНОСТЬ ПО ОБРАЗОВАТЕЛЬНЫМ ПРОГРАММАМ НАЧАЛЬНОГО, ОСНОВНОГО И СРЕДНЕГО ОБЩЕГО ОБРАЗОВАНИЯ (на начало учебного года; тысяч человек)',
#   'Unnamed: 264',
#   'Unnamed: 265',
#   'Unnamed: 266',
#   'Unnamed: 267'],
#  ['ЧИСЛЕННОСТЬ СТУДЕНТОВ, ОБУЧАЮЩИХСЯ ПО ПРОГРАММАМ ПОДГОТОВКИ КВАЛИФИЦИРОВАННЫХ РАБОЧИХ, СЛУЖАЩИХ,(на конец года;тысяч человек)',
#   'Unnamed: 279',
#   'Unnamed: 280',
#   'Unnamed: 281',
#   'Unnamed: 282'],
#  ['ПРИЕМ НА ОБУЧЕНИЕ ПО ПРОГРАММАМ ПОДГОТОВКИ КВАЛИФИЦИРОВАННЫХ РАБОЧИХ, СЛУЖАЩИХ,  (тысяч человек)',
#   'Unnamed: 284',
#   'Unnamed: 285',
#   'Unnamed: 286',
#   'Unnamed: 287'],
#  ['ВЫПУСК КВАЛИФИЦИРОВАННЫХ РАБОЧИХ И СЛУЖАЩИХ, (тысяч человек)',
#   'Unnamed: 289',
#   'Unnamed: 290',
#   'Unnamed: 291',
#   'Unnamed: 292'],
#  ['ЧИСЛЕННОСТЬ СТУДЕНТОВ, ОБУЧАЮЩИХСЯ ПО ПРОГРАММАМ ПОДГОТОВКИ СПЕЦИАЛИСТОВ СРЕДНЕГО ЗВЕНА, (на начало учебного года; тысяч человек)',
#   'Unnamed: 294',
#   'Unnamed: 295',
#   'Unnamed: 296',
#   'Unnamed: 297'],
#  ['ЧИСЛЕННОСТЬ СТУДЕНТОВ ГОСУДАРСТВЕННЫХ И МУНИЦИПАЛЬНЫХ ПРОФЕССИОНАЛЬНЫХ ОБРАЗОВАТЕЛЬНЫХ ОРГАНИЗАЦИЙ, ОБУЧАЮЩИХСЯ ПО ПРОГРАММАМ ПОДГОТОВКИ СПЕЦИАЛИСТОВ СРЕДНЕГО ЗВЕНА на 10 000 человек населения, (на начало учебного года; человек)',
#   'Unnamed: 299',
#   'Unnamed: 300',
#   'Unnamed: 301',
#   'Unnamed: 302'],
#  ['ПРИЕМ НА ОБУЧЕНИЕ ПО ПРОГРАММАМ ПОДГОТОВКИ СПЕЦИАЛИСТОВ СРЕДНЕГО ЗВЕНА, (тысяч человек)',
#   'Unnamed: 304',
#   'Unnamed: 305',
#   'Unnamed: 306',
#   'Unnamed: 307'],
#  ['ВЫПУСК СПЕЦИАЛИСТОВ   СРЕДНЕГО ЗВЕНА, (тысяч человек)',
#   'Unnamed: 309',
#   'Unnamed: 310',
#   'Unnamed: 311',
#   'Unnamed: 312'],
#  ['ЧИСЛЕННОСТЬ СТУДЕНТОВ, ОБУЧАЮЩИХСЯ ПО ПРОГРАММАМ БАКАЛАВРИАТА, СПЕЦИАЛИТЕТА, МАГИСТРАТУРЫ, (на начало учебного года; тысяч человек) ',
#   'Unnamed: 314',
#   'Unnamed: 315',
#   'Unnamed: 316',
#   'Unnamed: 317'],
#  ['ЧИСЛЕННОСТЬ СТУДЕНТОВ, ОБУЧАЮЩИХСЯ ПО ПРОГРАММАМ БАКАЛАВРИАТА, СПЕЦИАЛИТЕТА, МАГИСТРАТУРЫ на 10 000 человек населения, (на начало учебного года; человек)',
#   'Unnamed: 319',
#   'Unnamed: 320',
#   'Unnamed: 321',
#   'Unnamed: 322'],
#  ['ПРИЕМ НА ОБУЧЕНИЕ ПО ПРОГРАММАМ БАКАЛАВРИАТА, СПЕЦИАЛИТЕТА, МАГИСТРАТУРЫ,  (тысяч человек)',
#   'Unnamed: 324',
#   'Unnamed: 325',
#   'Unnamed: 326',
#   'Unnamed: 327'],
#  ['ВЫПУСК БАКАЛАВРОВ, СПЕЦИАЛИСТОВ, МАГИСТРОВ, (тысяч человек)',
#   'Unnamed: 329',
#   'Unnamed: 330',
#   'Unnamed: 331',
#   'Unnamed: 332'],
#  ['23110000100030200007 Численность постоянного населения России по возрасту на 1 января, все население',
#   'Unnamed: 334',
#   'Unnamed: 335',
#   'Unnamed: 336',
#   'Unnamed: 337'],
#  ['23110000100030200007 Численность постоянного населения России по возрасту на 1 января, Всего в трудоспособном возрасте (для мужчин 16-59,для женщин 16-54)',
#   'Unnamed: 339',
#   'Unnamed: 340',
#   'Unnamed: 341',
#   'Unnamed: 342'],
#  ['23110000100030200007 Численность постоянного населения России по возрасту на 1 января, Старше трудоспособного',
#   'Unnamed: 344',
#   'Unnamed: 345',
#   'Unnamed: 346',
#   'Unnamed: 347'],
#  ['11111150100170200001 Протяженность автомобильных дорог общего пользования местного значения, находящихся в собственности муниципальных образований, Всего',
#   'Unnamed: 349',
#   'Unnamed: 350',
#   'Unnamed: 351',
#   'Unnamed: 352'],
#  ['11111150100170200001 Протяженность автомобильных дорог общего пользования местного значения, находящихся в собственности муниципальных образований, Отвечающие нормативным требованиям',
#   'Unnamed: 354',
#   'Unnamed: 355',
#   'Unnamed: 356',
#   'Unnamed: 357'],
#  ['Введено в действие общей площади жилых домов на 1000 человек населения (кв. метров общей площади жилых помещений)',
#   'Unnamed: 359',
#   'Unnamed: 360',
#   'Unnamed: 361',
#   'Unnamed: 362'],
#  ['Индекс производительности труда по Российской Федерации, по субъектам Российской Федерации в 2008-2022 г.г. (в % к предыдущему году)',
#   'Unnamed: 364',
#   'Unnamed: 365',
#   'Unnamed: 366',
#   'Unnamed: 367'],
#  ['Доля инвестиций в основной капитал к ВРП Доля  инвестиций в основной капитал к ВРП (в %)',
#   'Unnamed: 369',
#   'Unnamed: 370',
#   'Unnamed: 371',
#   'Unnamed: 372'],
#  ['Прирост высокопроизводительных рабочих мест по субъектам Российской Федерации за 2012-2022 гг. (тыс. единиц)',
#   'Unnamed: 374',
#   'Unnamed: 375',
#   'Unnamed: 376',
#   'Unnamed: 377'],
#  ['Прирост высокопроизводительных рабочих мест по субъектам Российской Федерации за 2012-2022 гг. (в %)',
#   'Unnamed: 379',
#   'Unnamed: 380',
#   'Unnamed: 381',
#   'Unnamed: 382'],
#  ['11111150100320200001 Плотность автомобильных дорог с твердым покрытием общего пользования на 1000 кв. км территории (по 2013 г.)',
#   'Unnamed: 384',
#   'Unnamed: 385',
#   'Unnamed: 386',
#   'Unnamed: 387'],
#  ['22720000300200200001 Общая численность пенсионеров',
#   'Unnamed: 389',
#   'Unnamed: 390',
#   'Unnamed: 391',
#   'Unnamed: 392'],
#  ['13230000100060200002 Численность врачей всех специальностей (физических лиц) в учреждениях, оказывающих медицинские услуги населению, на конец отчетного года(тыс. чел.)Терапевты',
#   'Unnamed: 394',
#   'Unnamed: 395',
#   'Unnamed: 396',
#   'Unnamed: 397'],
#  ['13230000100060200002 Численность врачей всех специальностей (физических лиц) в учреждениях, оказывающих медицинские услуги населению, на конец отчетного года(тыс. чел.)Всего врачей',
#   'Unnamed: 399',
#   'Unnamed: 400',
#   'Unnamed: 401',
#   'Unnamed: 402'],
#  ['22310000100520200001 Количество  введенных  жилых помещений ( квартир ) в расчете на 1000 человек населения',
#   'Unnamed: 404',
#   'Unnamed: 405',
#   'Unnamed: 406',
#   'Unnamed: 407'],
#  ['22310000200010200001 Средняя факт. стоимость строительства 1 кв.м. общей площади отдельно стоящих жилых домов без пристроек, надстроек и встроенных помещений, Отдельно стоящие здания жилого назначения квартирного типа',
#   'Unnamed: 409',
#   'Unnamed: 410',
#   'Unnamed: 411',
#   'Unnamed: 412'],
#  ['22310000100030200001 Введено в действие общей площади жилых домов на 1000 человек населения (годовая)',
#   'Unnamed: 414',
#   'Unnamed: 415',
#   'Unnamed: 416',
#   'Unnamed: 417'],
#  ['11411000200010200019 Объем инвестиций в основной капитал (за исключением бюджетных средств) с 2018 г.(тыс. руб.)',
#   'Unnamed: 419',
#   'Unnamed: 420',
#   'Unnamed: 421',
#   'Unnamed: 422'],
#  ['11111110200300200001 Текущая рыночная стоимость жилых зданий(млн. руб.)',
#   'Unnamed: 424',
#   'Unnamed: 425',
#   'Unnamed: 426',
#   'Unnamed: 427']]

# %%
index_regions = df[df.columns[2]].values[1:]
index_regions
# Out:
# array(['Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
#        'Костромская область', 'Курская область', 'Липецкая область',
#        'Московская область', 'Орловская область', 'Рязанская область',
#        'Смоленская область', 'Тамбовская область', 'Тверская область',
#        'Тульская область', 'Ярославская область',
#        'Город Москва столица Российской Федерации город федерального значения',
#        'Республика Карелия', 'Республика Коми',
#        'Ненецкий автономный округ (Архангельская область)',
#        'Архангельская область (кроме Ненецкого автономного округа)',
#        'Вологодская область', 'Калининградская область',
#        'Ленинградская область', 'Мурманская область',
#        'Новгородская область', 'Псковская область',
#        'Город Санкт-Петербург город федерального значения',
#        'Республика Адыгея (Адыгея)', 'Республика Калмыкия',
#        'Республика Крым', 'Краснодарский край', 'Астраханская область',
#        'Волгоградская область', 'Ростовская область',
#        'Город федерального значения Севастополь', 'Республика Дагестан',
#        'Республика Ингушетия', 'Кабардино-Балкарская Республика',
#        'Карачаево-Черкесская Республика',
#        'Республика Северная Осетия-Алания', 'Чеченская Республика',
#        'Ставропольский край', 'Республика Башкортостан',
#        'Республика Марий Эл', 'Республика Мордовия',
#        'Республика Татарстан (Татарстан)', 'Удмуртская Республика',
#        'Чувашская Республика - Чувашия', 'Пермский край',
#        'Кировская область', 'Нижегородская область',
#        'Оренбургская область', 'Пензенская область', 'Самарская область',
#        'Саратовская область', 'Ульяновская область', 'Курганская область',
#        'Свердловская область',
#        'Ханты-Мансийский автономный округ - Югра (Тюменская область)',
#        'Ямало-Ненецкий автономный округ (Тюменская область)',
#        'Тюменская область (кроме Ханты-Мансийского автономного округа-Югры и Ямало-Ненецкого автономного округа)',
#        'Челябинская область', 'Республика Алтай', 'Республика Тыва',
#        'Республика Хакасия', 'Алтайский край', 'Красноярский край',
#        'Иркутская область', 'Кемеровская область - Кузбасс',
#        'Новосибирская область', 'Омская область', 'Томская область',
#        'Республика Бурятия', 'Забайкальский край',
#        'Республика Саха (Якутия)', 'Камчатский край', 'Приморский край',
#        'Хабаровский край', 'Амурская область', 'Магаданская область',
#        'Сахалинская область', 'Еврейская автономная область',
#        'Чукотский автономный округ', nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan], dtype=object)

# %%
real_df = []
index_names = []
for col in true_blocks:
    name = df[col[0]].name
    unit = df[col]
    unit.columns = unit.iloc[0]
    unit = unit.drop(unit.index[0])
    unit.set_index(index_regions, inplace=True)
    unit.columns = [x for x in range(2018, 2023, 1)]
    unit = unit.reset_index()
    unit = unit.dropna(subset=['index'])
    real_df.append(unit)
    index_names.append(name)
real_df[0]
# Out:
#                            index       2018  2019       2020       2021  \
# 0           Белгородская область  18.151815  15.1  18.011895  16.998012
# 1               Брянская область   8.243243  10.1  10.943396  13.517442
# 2           Владимирская область  13.006135  10.5  12.648221  11.666667
# 3            Воронежская область  17.097416  13.4  15.937500  12.626656
# 4             Ивановская область   8.133971  10.0  16.196137  14.893617
# ..                           ...        ...   ...        ...        ...
# 80              Амурская область   6.250000   5.1   6.657790   5.947441
# 81           Магаданская область  10.326087  13.3   9.427609   9.121622
# 82           Сахалинская область   5.982906   5.0   4.809052   3.896104
# 83  Еврейская автономная область   7.246377   4.3   5.500000   4.494382
# 84    Чукотский автономный округ  12.500000   7.8   6.666667   9.036145
#
#          2022
# 0   15.130941
# 1   12.094395
# 2    9.867173
# 3   10.436714
# 4   13.756614
# ..        ...
# 80   6.824513
# 81   8.552632
# 82   4.848485
# 83   3.954802
# 84   7.471264
#
# [85 rows x 6 columns]

# %%
mrlted_ls = []

for col, name, unit in zip(true_blocks, index_names, real_df):
    melted_df = unit.melt(id_vars='index', var_name='period', value_name=name)
    mrlted_ls.append(melted_df)

# %%
merged_df = mrlted_ls[0]

for frame in mrlted_ls[1:]:
    merged_df = pd.concat([merged_df, frame[frame.columns[-1]]], axis=1)
merged_df
# Out:
#                             index period  \
# 0            Белгородская область   2018
# 1                Брянская область   2018
# 2            Владимирская область   2018
# 3             Воронежская область   2018
# 4              Ивановская область   2018
# ..                            ...    ...
# 420              Амурская область   2022
# 421           Магаданская область   2022
# 422           Сахалинская область   2022
# 423  Еврейская автономная область   2022
# 424    Чукотский автономный округ   2022
#
#      Уровень инновационной активности, в процентах (%)  \
# 0                                            18.151815
# 1                                             8.243243
# 2                                            13.006135
# 3                                            17.097416
# 4                                             8.133971
# ..                                                 ...
# 420                                           6.824513
# 421                                           8.552632
# 422                                           4.848485
# 423                                           3.954802
# 424                                           7.471264
#
#      Индекс производительности труда по Российской Федерации, \nпо субъектам Российской Федерации в 2008-2022 г.г. (в % к предыдущему году)  \
# 0                                                102.8
# 1                                                104.9
# 2                                                100.8
# 3                                                102.7
# 4                                                102.3
# ..                                                 ...
# 420                                              102.6
# 421                                               95.9
# 422                                               93.9
# 423                                               98.4
# 424                                               95.7
#
#      Уровень бедности, в процентах (%) от общей численности населения  \
# 0                                                  7.5
# 1                                                 13.6
# 2                                                 13.1
# 3                                                  8.9
# 4                                                 14.2
# ..                                                 ...
# 420                                               11.9
# 421                                                6.7
# 422                                                6.3
# 423                                               18.3
# 424                                                5.2
#
#      Индекс промышленного производства в % к соответствующему периоду предыдущего года  \
# 0                                                102.4
# 1                                                102.7
# 2                                                104.6
# 3                                                103.2
# 4                                                102.1
# ..                                                 ...
# 420                                              102.8
# 421                                              101.1
# 422                                               76.8
# 423                                              107.0
# 424                                               86.8
#
#      Распределение объема работ, выполненных по виду деятельности "Строительство" организациями различных форм собственности \n(без учета субъектов малого предпринимательства) \n(тыс. рублей)  \
# 0                                           23362304.1
# 1                                            5311814.7
# 2                                            5663657.5
# 3                                           29882520.9
# 4                                            4499339.9
# ..                                                 ...
# 420                                        158807105.1
# 421                                         15242720.8
# 422                                         68785826.1
# 423                                         11158163.2
# 424                                          8302038.9
#
#      Среднедушевые денежные доходы населения по субъектам Российской Федерации, руб./месяц  \
# 0                                         30712.962414
# 1                                         26722.337614
# 2                                         23343.519683
# 3                                         30158.281326
# 4                                         25421.329962
# ..                                                 ...
# 420                                       49798.000000
# 421                                      101999.000000
# 422                                       79322.000000
# 423                                       37753.000000
# 424                                      138161.000000
#
#      Численность занятых в возрасте 15 лет и старше по субъектам Российской Федерации (по данным выборочных обследований), тыс. человек   \
# 0                                              792.637
# 1                                              586.497
# 2                                              688.375
# 3                                             1141.811
# 4                                              502.984
# ..                                                 ...
# 420                                            382.853
# 421                                             80.746
# 422                                            261.753
# 423                                             72.355
# 424                                             28.690
#
#      Уровень занятости населения в возрасте 15 лет и старше по субъектам Российской Федерации (по данным выборочных обследований), в процентах  \
# 0                                                 60.6
# 1                                                 57.2
# 2                                                 58.7
# 3                                                 57.3
# 4                                                 58.2
# ..                                                 ...
# 420                                               61.1
# 421                                               71.2
# 422                                               67.1
# 423                                               58.6
# 424                                               76.4
#
#      ...  \
# 0    ...
# 1    ...
# 2    ...
# 3    ...
# 4    ...
# ..   ...
# 420  ...
# 421  ...
# 422  ...
# 423  ...
# 424  ...
#
#      Прирост высокопроизводительных рабочих мест по субъектам Российской Федерации за 2012-2022 гг. (в %)  \
# 0                                                 16,7
# 1                                                 10,6
# 2                                                 15,0
# 3                                                 19,9
# 4                                                 15,7
# ..                                                 ...
# 420                                                2,4
# 421                                                4,9
# 422                                               16,5
# 423                                               -3,3
# 424                                                4,6
#
#     11111150100320200001 Плотность автомобильных дорог с твердым покрытием общего пользования на 1000 кв. км территории (по 2013 г.)  \
# 0                                                  731
# 1                                                  320
# 2                                                  347
# 3                                                  359
# 4                                                  334
# ..                                                 ...
# 420                                                 35
# 421                                               5,60
# 422                                                 33
# 423                                                 71
# 424                                               1,30
#
#      22720000300200200001 Общая численность пенсионеров  \
# 0                                                  539
# 1                                                  439
# 2                                                  489
# 3                                               797,99
# 4                                               346,99
# ..                                                 ...
# 420                                                238
# 421                                              45,99
# 422                                             168,99
# 423                                              47,99
# 424                                                 16
#
#      13230000100060200002 Численность врачей всех специальностей (физических лиц) в учреждениях, оказывающих медицинские услуги населению, на конец отчетного года(тыс. чел.)Терапевты  \
# 0                                                 0,46
# 1                                                 0,59
# 2                                                 0,62
# 3                                                 1,06
# 4                                                 0,56
# ..                                                 ...
# 420                                               1,07
# 421                                               0,78
# 422                                               0,54
# 423                                               0,09
# 424                                               0,38
#
#      13230000100060200002 Численность врачей всех специальностей (физических лиц) в учреждениях, оказывающих медицинские услуги населению, на конец отчетного года(тыс. чел.)Всего врачей  \
# 0                                                 6,26
# 1                                                 4,86
# 2                                                 4,76
# 3                                                12,16
# 4                                                 4,44
# ..                                                 ...
# 420                                               9,56
# 421                                               7,09
# 422                                               4,27
# 423                                               0,84
# 424                                               3,20
#
#      22310000100520200001 Количество  введенных  жилых помещений ( квартир ) в расчете на 1000 человек населения  \
# 0                                                 7,70
# 1                                                 5,09
# 2                                                 5,50
# 3                                                 9,40
# 4                                                 4,50
# ..                                                 ...
# 420                                               6,90
# 421                                               1,40
# 422                                              15,40
# 423                                               1,70
# 424                                               1,20
#
#     22310000200010200001 Средняя факт. стоимость строительства 1 кв.м. общей площади отдельно стоящих жилых домов без пристроек, надстроек и встроенных помещений, Отдельно стоящие здания жилого назначения квартирного типа  \
# 0                                                47772
# 1                                                30541
# 2                                             31854,99
# 3                                                32583
# 4                                                29309
# ..                                                 ...
# 420                                              53775
# 421                                          188901,99
# 422                                                NaN
# 423                                                NaN
# 424                                                NaN
#
#      22310000100030200001 Введено в действие общей площади жилых домов на 1000 человек населения (годовая)  \
# 0                                                  785
# 1                                                  334
# 2                                                  476
# 3                                                  726
# 4                                                  366
# ..                                                 ...
# 420                                                498
# 421                                                 85
# 422                                               1088
# 423                                                170
# 424                                                 74
#
#     11411000200010200019 Объем инвестиций в основной капитал (за исключением бюджетных средств) с 2018 г.(тыс. руб.)  \
# 0                                            122692316
# 1                                          51322637,99
# 2                                             64891800
# 3                                         237032908,99
# 4                                             26071299
# ..                                                 ...
# 420                                       445380621,99
# 421                                        67783415,99
# 422                                       234063071,99
# 423                                        18087344,99
# 424                                           65684137
#
#      11111110200300200001 Текущая рыночная стоимость жилых зданий(млн. руб.)
# 0                                           1305087,99
# 1                                            727575,99
# 2                                            927909,99
# 3                                           1364237,99
# 4                                            500732,99
# ..                                                 ...
# 420                                          125263,99
# 421                                          429248,99
# 422                                           94554,99
# 423                                           16654,99
# 424                                                NaN
#
# [425 rows x 85 columns]

# %%
merged_df.to_excel('panel.xlsx', index=False)
